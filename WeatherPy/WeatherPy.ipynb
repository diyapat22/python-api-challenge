# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %% [markdown]
# ---

# %%
cities
# Out:
# ['tralee',
#  'vila franca do campo',
#  'spittal an der drau',
#  'hasaki',
#  'invercargill',
#  'valle hermoso',
#  'puerto natales',
#  'stanley',
#  'port-aux-francais',
#  'papatowai',
#  'longyearbyen',
#  'adamstown',
#  'rawson',
#  'kikvidze',
#  'daru',
#  'yashan',
#  'palopo',
#  'del rio',
#  'mount pearl',
#  'ushuaia',
#  'thisted',
#  'antsohihy',
#  'waitangi',
#  'kapit',
#  'port elizabeth',
#  'taiohae',
#  'nogliki',
#  'port alfred',
#  'santa cruz',
#  'nkurenkuru',
#  'kirakira',
#  'munstertal/schwarzwald',
#  'nova vicosa',
#  'klyuchi',
#  'grytviken',
#  'jiuquan',
#  'tambopata',
#  'sitka',
#  'souillac',
#  'lamu',
#  "t'aebaek",
#  'tiksi',
#  'jamestown',
#  'sirte',
#  'edinburgh of the seven seas',
#  'valparaiso',
#  'aljezur',
#  'aasiaat',
#  'bikenibeu village',
#  'port mathurin',
#  'tura',
#  'george town',
#  'lihue',
#  'port lincoln',
#  'ilulissat',
#  'glasgow',
#  'kibungo',
#  'ballina',
#  'tolanaro',
#  'miyaly',
#  'teruel',
#  'torre de moncorvo',
#  "la'ie",
#  'vila velha',
#  'muynoq',
#  'georgetown',
#  'talnakh',
#  'hermanus',
#  'chui',
#  'shiqian',
#  'faaborg',
#  'qaqortoq',
#  'utrik',
#  'sao gabriel da cachoeira',
#  'uturoa',
#  'santa vitoria do palmar',
#  'iqaluit',
#  'phan rang-thap cham',
#  'fort bragg',
#  'altamira',
#  'kapuskasing',
#  'albany',
#  'recreio',
#  'aripuana',
#  'kidal',
#  'willemstad',
#  'alice springs',
#  'nha trang',
#  'kulia village',
#  'fereydun kenar',
#  'yerofey pavlovich',
#  'beyneu',
#  'laascaanood',
#  'kedrovyy',
#  'notodden',
#  'dauphin',
#  'horta',
#  'aykhal',
#  'natal',
#  'enewetak',
#  'vorgashor',
#  'valentin gomez farias',
#  'minas de marcona',
#  'yellowknife',
#  'sur',
#  'sisimiut',
#  'margaret river',
#  'izluchinsk',
#  'zaraza',
#  'riberalta',
#  'wanning',
#  'palmer',
#  'bilibino',
#  'hawaiian paradise park',
#  'bardai',
#  'ryazanskaya',
#  'flying fish cove',
#  'san antonio de pale',
#  'chonchi',
#  'inirida',
#  'blackmans bay',
#  'hami',
#  'west island',
#  'san marcos',
#  'nuuk',
#  'new ulm',
#  'bethel',
#  'puerto real',
#  'ketchikan',
#  'okha',
#  'tazovsky',
#  "nar'yan-mar",
#  'sumbe',
#  'idrinskoye',
#  'avarua',
#  'alofi',
#  'churapcha',
#  'lokhvytsya',
#  "kapa'a",
#  'kargasok',
#  'martapura',
#  'semporna',
#  'naze',
#  'glendive',
#  'ankang',
#  'am djarass',
#  'yuzhno-kurilsk',
#  'smolyaninovo',
#  'melfi',
#  'anadyr',
#  'masterton',
#  'fasa',
#  'vadso',
#  'amboise',
#  'remire-montjoly',
#  'itapolis',
#  'dukhan',
#  'nemuro',
#  'merizo village',
#  'ciudad constitucion',
#  'kawalu',
#  'meizhou',
#  'geraldton',
#  'malesherbes',
#  "kapyl'",
#  'isafjordur',
#  'norman gardens',
#  'bredasdorp',
#  'sorong',
#  'qamdo',
#  'pesqueira',
#  'atafu village',
#  'gizo',
#  'east london',
#  'as sulayyil',
#  'plettenberg bay',
#  'ustka',
#  'vingt cinq',
#  'dunedin',
#  'saudarkrokur',
#  'dudinka',
#  'guerrero negro',
#  'kodiak',
#  'olonkinbyen',
#  'lorengau',
#  'camarinas',
#  'kiunga',
#  'bure',
#  'viedma',
#  'coquimbo',
#  'labrador city',
#  'al-`ula',
#  'st. paul',
#  "arkhangel'sk",
#  'winejok',
#  'beau vallon',
#  "st. john's",
#  'nur-sultan',
#  'haiku-pauwela',
#  'shingu',
#  'vilyuchinsk',
#  'san agustin de valle fertil',
#  'calella',
#  'banda aceh',
#  'faya-largeau',
#  'newman',
#  'fuvahmulah',
#  'binissalem',
#  'chernyshevskiy',
#  'amahai',
#  'sishilichengzi',
#  'xichang',
#  'cadale',
#  'calgary',
#  'sao bento',
#  'pierre',
#  'howrah',
#  'fortuna',
#  'navarcles',
#  'palmerston north',
#  'kouroussa',
#  'apucarana',
#  'alotau',
#  'bengkulu',
#  'yardimli',
#  'kawthoung',
#  'kardla',
#  'san andres',
#  'badger',
#  'kamloops',
#  'kristiansund',
#  'puerto ayora',
#  'dalnegorsk',
#  'fisterra',
#  "port saint john's",
#  'lebu',
#  'viana do castelo',
#  'susanville',
#  'college',
#  'samalut',
#  'san ignacio',
#  'cutro',
#  'berryville',
#  'udachny',
#  'inarajan village',
#  'beohari',
#  'walvis bay',
#  'ujae',
#  'ozalp',
#  'colonia',
#  'al bawiti',
#  'mikumi',
#  'necochea',
#  'whitehorse',
#  'kingaroy',
#  'mazatlan',
#  'douentza',
#  'nadym',
#  'nikolayevsk-on-amure',
#  'rongelap',
#  'farasan',
#  'barda',
#  'pemba',
#  'labuan bajo',
#  'ancud',
#  'grand falls-windsor',
#  'el monte',
#  'pisco',
#  'weno',
#  'petropavlovsk-kamchatsky',
#  'yreka',
#  'thompson',
#  'lompoc',
#  'mata-utu',
#  'zeya',
#  'kingston',
#  'nova sintra',
#  'shenkursk',
#  'selfoss',
#  'hamilton',
#  'kerikeri',
#  'polyarnyy',
#  'seeb',
#  'ciudad rodrigo',
#  'khanty-mansiysk',
#  'murun-kuren',
#  'okhotsk',
#  'piti village',
#  'ilhabela',
#  'afaahiti',
#  'boguchany',
#  'tsiombe',
#  'chibougamau',
#  'tselinnoye',
#  'nabire',
#  'bel ombre',
#  'wailua homesteads',
#  'sinabang',
#  'constantia',
#  'bandon',
#  'nizhniy odes',
#  'port lavaca',
#  'at taj',
#  'punta arenas',
#  'mojo',
#  'chatillon-sur-seine',
#  'salinas',
#  'canarana',
#  'majene',
#  'hithadhoo',
#  'la tuque',
#  'vanino',
#  'puerto san carlos',
#  'el granada',
#  'pimenta bueno',
#  'keflavik',
#  'paoy paet',
#  'puerto baquerizo moreno',
#  'dan sadau',
#  'samana',
#  'novodvinsk',
#  'teknaf',
#  'ust-tsilma',
#  'veinticinco de mayo',
#  'timmins',
#  'khovd',
#  'ilawa',
#  'castillos',
#  'bubaque',
#  'antofagasta',
#  'starotitarovskaya',
#  'prince rupert',
#  'codrington',
#  'kukawa',
#  'concepcion',
#  'tuam',
#  'smithers',
#  'bokajan',
#  'nicoya',
#  'ribeira brava',
#  'boyabat',
#  'masjed soleyman',
#  'ust-nera',
#  'taroa',
#  'kolokani',
#  'al jawf',
#  'burang',
#  'baikonur',
#  'hopelchen',
#  'cidreira',
#  'vilhena',
#  'qarqaraly',
#  'magadan',
#  'lodja',
#  'taibet',
#  'dezhou',
#  'karratha',
#  'tibati',
#  'concepcion del oro',
#  'yaren',
#  'orsk',
#  "muzayri'",
#  'xining',
#  'ola',
#  'al fqih ben calah',
#  'crane',
#  'aswan',
#  'klintsy',
#  'betare oya',
#  'kone',
#  'praia da vitoria',
#  'lagoa',
#  'taft',
#  'ubari',
#  'luderitz',
#  "dem'yanovo",
#  'khandyga',
#  'barah',
#  'kwale',
#  'portland',
#  'brokopondo',
#  'rabigh',
#  'saint-philippe',
#  'aioun',
#  'prince george',
#  'quillacollo',
#  'wau',
#  'akbarabad',
#  "ytyk-kyuyel'",
#  'ourinhos',
#  'saipan',
#  'zhangye',
#  'massawa',
#  'gadzhiyevo',
#  'touros',
#  'inhambane',
#  'prado',
#  'coahuayana de hidalgo',
#  'salekhard',
#  'khuzdar',
#  'paradip garh',
#  'nam som',
#  'usogorsk',
#  'beloyarskiy',
#  'ilam',
#  'lubango',
#  'adrar',
#  'dhidhdhoo',
#  'port douglas',
#  'shahrud',
#  'tofol',
#  'guilmaro',
#  'kununurra',
#  'nenjiang',
#  "hayma'",
#  'usinsk',
#  'almaty',
#  'homer',
#  'santiago papasquiaro',
#  'waingapu',
#  'fale old settlement',
#  'wonsan',
#  'gamba',
#  'posto fiscal rolim de moura',
#  'nyrob',
#  'kuruman',
#  'kilindoni',
#  'kavieng',
#  'pasni',
#  'tengrela',
#  'christchurch',
#  'qorveh',
#  'poddebice',
#  'puerto armuelles',
#  'tobi village',
#  'ribeira grande',
#  'benghazi',
#  'rio grande',
#  'dzuunharaa',
#  'tucuma',
#  'aldan',
#  'darya khan',
#  'margate',
#  'metlili chaamba',
#  'pea ridge',
#  'tonghae',
#  'mariental',
#  'porto novo',
#  'gallup',
#  'kruisfontein',
#  'guiping',
#  'san patricio',
#  'harper',
#  'makinsk',
#  'flin flon',
#  'tranovaho',
#  'san mariano',
#  'ulaangom',
#  'zalingei',
#  'cambria',
#  'sosnovo-ozerskoye',
#  'umba',
#  'lensk',
#  'tocopilla',
#  'severo-yeniseyskiy',
#  'kiffa',
#  'envira',
#  'yelovo',
#  'sorochinsk',
#  'mina clavero',
#  'sitampiky',
#  'aghstafa',
#  'cholpon-ata',
#  'west bay',
#  'isangel',
#  'iguai',
#  'yung shue wan',
#  'nyurba',
#  'nakonde',
#  'ulsteinvik',
#  'jaora',
#  'padang',
#  'ubinskoye',
#  'vallenar',
#  'tamandare',
#  'o barco de valdeorras',
#  'queensbury',
#  'plouzane',
#  'labytnangi',
#  'iskateley',
#  'terrace',
#  'nagar karnul',
#  'kathu',
#  'bukama',
#  "novyy turtkul'",
#  'alaghsas',
#  'gevas',
#  'sinop',
#  'igarka',
#  'saint-pierre',
#  'san luis de la loma',
#  'peace river',
#  'madalena',
#  'tocancipa',
#  'kismayo',
#  'lai',
#  'leua',
#  'kazanka',
#  'mchinji',
#  'constitucion',
#  'oranjemund',
#  'san pablo villa de mitla',
#  'salinopolis',
#  'altania',
#  'altai',
#  'namibe',
#  'mahabe',
#  "sa'dah",
#  'mount isa',
#  'cabo san lucas',
#  'luanshya',
#  'seybaplaya',
#  'tanrake village',
#  'piacabucu',
#  'bodaybo',
#  'lind',
#  'lang son',
#  'kayenta',
#  'lawas',
#  'tindouf',
#  'holualoa',
#  'barcelos',
#  'happy valley-goose bay',
#  'guiuan',
#  'xilin hot',
#  'mar del plata',
#  'quellon',
#  'merano',
#  'zavetnoye',
#  'road town',
#  'haimen',
#  'ilomantsi',
#  'susuman',
#  'lhokseumawe',
#  'nizhneudinsk',
#  'tevragh zeina',
#  "nuku'alofa",
#  'cururupu',
#  'kot ghulam muhammad',
#  'sal rei',
#  'dombarovskiy',
#  'maitum',
#  'giado',
#  'shar',
#  "cooper's town",
#  'arraial do cabo',
#  'petropavlovka',
#  'mingshui',
#  'berberati',
#  'lazaro cardenas',
#  'isle of lewis',
#  'vangaindrano',
#  'gaalkacyo',
#  'mount gambier',
#  'menderes',
#  'cacule',
#  'tazacorte',
#  'mersing',
#  'wamba',
#  'langzhong',
#  'cartagena',
#  'turpan',
#  'nishinoomote',
#  'chiredzi',
#  'bandar abbas',
#  'inza',
#  'ulanhot',
#  'fort mcmurray',
#  'kwidzyn',
#  'lesozavodsk',
#  'houlton',
#  'helena valley southeast',
#  'taro',
#  'svendborg',
#  'fortaleza',
#  'astrakhan',
#  'barkhan',
#  'zarand',
#  'jeremie',
#  'taseyevo',
#  'nejo',
#  'sokode',
#  'richards bay',
#  'butte',
#  'mermoz boabab',
#  'as suwayq',
#  'saint-leu',
#  'palangkaraya',
#  'espinosa',
#  'srandakan',
#  'soller',
#  "al bayda'",
#  'akureyri',
#  'i-n-salah',
#  'itumba',
#  'al bardiyah',
#  'yinchuan',
#  'rosario',
#  'barra de santo antonio',
#  'labuan',
#  'zajas',
#  'ebish',
#  'la passe',
#  'port shepstone',
#  'pontianak',
#  'derzhavinsk',
#  'parral',
#  'mangrol']

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]      

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tralee
# Processing Record 2 of Set 1 | vila franca do campo
# Processing Record 3 of Set 1 | spittal an der drau
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | invercargill
# Processing Record 6 of Set 1 | valle hermoso
# Processing Record 7 of Set 1 | puerto natales
# Processing Record 8 of Set 1 | stanley
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | papatowai
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | rawson
# Processing Record 14 of Set 1 | kikvidze
# Processing Record 15 of Set 1 | daru
# Processing Record 16 of Set 1 | yashan
# Processing Record 17 of Set 1 | palopo
# Processing Record 18 of Set 1 | del rio
# Processing Record 19 of Set 1 | mount pearl
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | thisted
# Processing Record 22 of Set 1 | antsohihy
# Processing Record 23 of Set 1 | waitangi
# Processing Record 24 of Set 1 | kapit
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 27 of Set 1 | nogliki
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | santa cruz
# Processing Record 30 of Set 1 | nkurenkuru
# City not found. Skipping...
# Processing Record 31 of Set 1 | kirakira
# Processing Record 32 of Set 1 | munstertal/schwarzwald
# City not found. Skipping...
# Processing Record 33 of Set 1 | nova vicosa
# Processing Record 34 of Set 1 | klyuchi
# Processing Record 35 of Set 1 | grytviken
# Processing Record 36 of Set 1 | jiuquan
# Processing Record 37 of Set 1 | tambopata
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | lamu
# Processing Record 41 of Set 1 | t'aebaek
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | sirte
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# Processing Record 46 of Set 1 | valparaiso
# Processing Record 47 of Set 1 | aljezur
# Processing Record 48 of Set 1 | aasiaat
# Processing Record 49 of Set 1 | bikenibeu village
# Processing Record 50 of Set 1 | port mathurin
# Processing Record 0 of Set 2 | tura
# Processing Record 1 of Set 2 | george town
# Processing Record 2 of Set 2 | lihue
# Processing Record 3 of Set 2 | port lincoln
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | glasgow
# Processing Record 6 of Set 2 | kibungo
# Processing Record 7 of Set 2 | ballina
# Processing Record 8 of Set 2 | tolanaro
# Processing Record 9 of Set 2 | miyaly
# Processing Record 10 of Set 2 | teruel
# Processing Record 11 of Set 2 | torre de moncorvo
# Processing Record 12 of Set 2 | la'ie
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | muynoq
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | chui
# Processing Record 19 of Set 2 | shiqian
# Processing Record 20 of Set 2 | faaborg
# Processing Record 21 of Set 2 | qaqortoq
# Processing Record 22 of Set 2 | utrik
# Processing Record 23 of Set 2 | sao gabriel da cachoeira
# Processing Record 24 of Set 2 | uturoa
# Processing Record 25 of Set 2 | santa vitoria do palmar
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | phan rang-thap cham
# Processing Record 28 of Set 2 | fort bragg
# Processing Record 29 of Set 2 | altamira
# Processing Record 30 of Set 2 | kapuskasing
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | recreio
# Processing Record 33 of Set 2 | aripuana
# Processing Record 34 of Set 2 | kidal
# Processing Record 35 of Set 2 | willemstad
# Processing Record 36 of Set 2 | alice springs
# Processing Record 37 of Set 2 | nha trang
# Processing Record 38 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | malesherbes
# Processing Record 14 of Set 4 | kapyl'
# City not found. Skipping...
# Processing Record 15 of Set 4 | isafjordur
# Processing Record 16 of Set 4 | norman gardens
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | sorong
# Processing Record 19 of Set 4 | qamdo
# Processing Record 20 of Set 4 | pesqueira
# Processing Record 21 of Set 4 | atafu village
# Processing Record 22 of Set 4 | gizo
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | as sulayyil
# Processing Record 25 of Set 4 | plettenberg bay
# Processing Record 26 of Set 4 | ustka
# Processing Record 27 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 28 of Set 4 | dunedin
# Processing Record 29 of Set 4 | saudarkrokur
# Processing Record 30 of Set 4 | dudinka
# Processing Record 31 of Set 4 | guerrero negro
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | olonkinbyen
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | camarinas
# Processing Record 36 of Set 4 | kiunga
# Processing Record 37 of Set 4 | bure
# Processing Record 38 of Set 4 | viedma
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | labrador city
# Processing Record 41 of Set 4 | al-`ula
# City not found. Skipping...
# Processing Record 42 of Set 4 | st. paul
# Processing Record 43 of Set 4 | arkhangel'sk
# Processing Record 44 of Set 4 | winejok
# City not found. Skipping...
# Processing Record 45 of Set 4 | beau vallon
# Processing Record 46 of Set 4 | st. john's
# Processing Record 47 of Set 4 | nur-sultan
# Processing Record 48 of Set 4 | haiku-pauwela
# Processing Record 49 of Set 4 | shingu
# Processing Record 0 of Set 5 | vilyuchinsk
# Processing Record 1 of Set 5 | san agustin de valle fertil
# Processing Record 2 of Set 5 | calella
# Processing Record 3 of Set 5 | banda aceh
# Processing Record 4 of Set 5 | faya-largeau
# Processing Record 5 of Set 5 | newman
# Processing Record 6 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 7 of Set 5 | binissalem
# Processing Record 8 of Set 5 | chernyshevskiy
# Processing Record 9 of Set 5 | amahai
# Processing Record 10 of Set 5 | sishilichengzi
# City not found. Skipping...
# Processing Record 11 of Set 5 | xichang
# Processing Record 12 of Set 5 | cadale
# Processing Record 13 of Set 5 | calgary
# Processing Record 14 of Set 5 | sao bento
# Processing Record 15 of Set 5 | pierre
# Processing Record 16 of Set 5 | howrah
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | navarcles
# Processing Record 19 of Set 5 | palmerston north
# Processing Record 20 of Set 5 | kouroussa
# Processing Record 21 of Set 5 | apucarana
# Processing Record 22 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 5 | bengkulu
# Processing Record 24 of Set 5 | yardimli
# Processing Record 25 of Set 5 | kawthoung
# City not found. Skipping...
# Processing Record 26 of Set 5 | kardla
# Processing Record 27 of Set 5 | san andres
# Processing Record 28 of Set 5 | badger
# Processing Record 29 of Set 5 | kamloops
# Processing Record 30 of Set 5 | kristiansund
# Processing Record 31 of Set 5 | puerto ayora
# Processing Record 32 of Set 5 | dalnegorsk
# Processing Record 33 of Set 5 | fisterra
# Processing Record 34 of Set 5 | port saint john's
# City not found. Skipping...
# Processing Record 35 of Set 5 | lebu
# City not found. Skipping...
# Processing Record 36 of Set 5 | viana do castelo
# City not found. Skipping...
# Processing Record 37 of Set 5 | susanville
# Processing Record 38 of Set 5 | college
# Processing Record 39 of Set 5 | samalut
# Processing Record 40 of Set 5 | san ignacio
# Processing Record 41 of Set 5 | cutro
# Processing Record 42 of Set 5 | berryville
# Processing Record 43 of Set 5 | udachny
# Processing Record 44 of Set 5 | inarajan village
# Processing Record 45 of Set 5 | beohari
# Processing Record 46 of Set 5 | walvis bay
# Processing Record 47 of Set 5 | ujae
# Processing Record 48 of Set 5 | ozalp
# Processing Record 49 of Set 5 | colonia
# Processing Record 0 of Set 6 | al bawiti
# Processing Record 1 of Set 6 | mikumi
# Processing Record 2 of Set 6 | necochea
# Processing Record 3 of Set 6 | whitehorse
# Processing Record 4 of Set 6 | kingaroy
# Processing Record 5 of Set 6 | mazatlan
# Processing Record 6 of Set 6 | douentza
# Processing Record 7 of Set 6 | nadym
# Processing Record 8 of Set 6 | nikolayevsk-on-amure
# Processing Record 9 of Set 6 | rongelap
# Processing Record 10 of Set 6 | farasan
# Processing Record 11 of Set 6 | barda
# Processing Record 12 of Set 6 | pemba
# Processing Record 13 of Set 6 | labuan bajo
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | grand falls-windsor
# Processing Record 16 of Set 6 | el monte
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | weno
# Processing Record 19 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 20 of Set 6 | yreka
# Processing Record 21 of Set 6 | thompson
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | mata-utu
# Processing Record 24 of Set 6 | zeya
# Processing Record 25 of Set 6 | kingston
# Processing Record 26 of Set 6 | nova sintra
# Processing Record 27 of Set 6 | shenkursk
# Processing Record 28 of Set 6 | selfoss
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | kerikeri
# Processing Record 31 of Set 6 | polyarnyy
# Processing Record 32 of Set 6 | seeb
# Processing Record 33 of Set 6 | ciudad rodrigo
# Processing Record 34 of Set 6 | khanty-mansiysk
# Processing Record 35 of Set 6 | murun-kuren
# Processing Record 36 of Set 6 | okhotsk
# Processing Record 37 of Set 6 | piti village
# Processing Record 38 of Set 6 | ilhabela
# Processing Record 39 of Set 6 | afaahiti
# Processing Record 40 of Set 6 | boguchany
# Processing Record 41 of Set 6 | tsiombe
# Processing Record 42 of Set 6 | chibougamau
# Processing Record 43 of Set 6 | tselinnoye
# Processing Record 44 of Set 6 | nabire
# Processing Record 45 of Set 6 | bel ombre
# Processing Record 46 of Set 6 | wailua homesteads
# Processing Record 47 of Set 6 | sinabang
# Processing Record 48 of Set 6 | constantia
# Processing Record 49 of Set 6 | bandon
# Processing Record 0 of Set 7 | nizhniy odes
# Processing Record 1 of Set 7 | port lavaca
# Processing Record 2 of Set 7 | at taj
# Processing Record 3 of Set 7 | punta arenas
# Processing Record 4 of Set 7 | mojo
# Processing Record 5 of Set 7 | chatillon-sur-seine
# Processing Record 6 of Set 7 | salinas
# Processing Record 7 of Set 7 | canarana
# Processing Record 8 of Set 7 | majene
# Processing Record 9 of Set 7 | hithadhoo
# Processing Record 10 of Set 7 | la tuque
# Processing Record 11 of Set 7 | vanino
# Processing Record 12 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record
of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 6 of Set 10 | san mariano
# Processing Record 7 of Set 10 | ulaangom
# Processing Record 8 of Set 10 | zalingei
# Processing Record 9 of Set 10 | cambria
# Processing Record 10 of Set 10 | sosnovo-ozerskoye
# Processing Record 11 of Set 10 | umba
# Processing Record 12 of Set 10 | lensk
# Processing Record 13 of Set 10 | tocopilla
# Processing Record 14 of Set 10 | severo-yeniseyskiy
# Processing Record 15 of Set 10 | kiffa
# Processing Record 16 of Set 10 | envira
# Processing Record 17 of Set 10 | yelovo
# Processing Record 18 of Set 10 | sorochinsk
# Processing Record 19 of Set 10 | mina clavero
# Processing Record 20 of Set 10 | sitampiky
# City not found. Skipping...
# Processing Record 21 of Set 10 | aghstafa
# Processing Record 22 of Set 10 | cholpon-ata
# Processing Record 23 of Set 10 | west bay
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | iguai
# Processing Record 26 of Set 10 | yung shue wan
# Processing Record 27 of Set 10 | nyurba
# Processing Record 28 of Set 10 | nakonde
# Processing Record 29 of Set 10 | ulsteinvik
# Processing Record 30 of Set 10 | jaora
# Processing Record 31 of Set 10 | padang
# Processing Record 32 of Set 10 | ubinskoye
# Processing Record 33 of Set 10 | vallenar
# Processing Record 34 of Set 10 | tamandare
# Processing Record 35 of Set 10 | o barco de valdeorras
# Processing Record 36 of Set 10 | queensbury
# Processing Record 37 of Set 10 | plouzane
# Processing Record 38 of Set 10 | labytnangi
# Processing Record 39 of Set 10 | iskateley
# Processing Record 40 of Set 10 | terrace
# Processing Record 41 of Set 10 | nagar karnul
# Processing Record 42 of Set 10 | kathu
# Processing Record 43 of Set 10 | bukama
# Processing Record 44 of Set 10 | novyy turtkul'
# Processing Record 45 of Set 10 | alaghsas
# Processing Record 46 of Set 10 | gevas
# Processing Record 47 of Set 10 | sinop
# Processing Record 48 of Set 10 | igarka
# Processing Record 49 of Set 10 | saint-pierre
# Processing Record 0 of Set 11 | san luis de la loma
# Processing Record 1 of Set 11 | peace river
# Processing Record 2 of Set 11 | madalena
# Processing Record 3 of Set 11 | tocancipa
# Processing Record 4 of Set 11 | kismayo
# Processing Record 5 of Set 11 | lai
# Processing Record 6 of Set 11 | leua
# Processing Record 7 of Set 11 | kazanka
# Processing Record 8 of Set 11 | mchinji
# Processing Record 9 of Set 11 | constitucion
# Processing Record 10 of Set 11 | oranjemund
# Processing Record 11 of Set 11 | san pablo villa de mitla
# Processing Record 12 of Set 11 | salinopolis
# Processing Record 13 of Set 11 | altania
# Processing Record 14 of Set 11 | altai
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | mahabe
# City not found. Skipping...
# Processing Record 17 of Set 11 | sa'dah
# Processing Record 18 of Set 11 | mount isa
# Processing Record 19 of Set 11 | cabo san lucas
# Processing Record 20 of Set 11 | luanshya
# Processing Record 21 of Set 11 | seybaplaya
# Processing Record 22 of Set 11 | tanrake village
# City not found. Skipping...
# Processing Record 23 of Set 11 | piacabucu
# Processing Record 24 of Set 11 | bodaybo
# Processing Record 25 of Set 11 | lind
# Processing Record 26 of Set 11 | lang son
# Processing Record 27 of Set 11 | kayenta
# Processing Record 28 of Set 11 | lawas
# Processing Record 29 of Set 11 | tindouf
# Processing Record 30 of Set 11 | holualoa
# Processing Record 31 of Set 11 | barcelos
# Processing Record 32 of Set 11 | happy valley-goose bay
# Processing Record 33 of Set 11 | guiuan
# Processing Record 34 of Set 11 | xilin hot
# Processing Record 35 of Set 11 | mar del plata
# Processing Record 36 of Set 11 | quellon
# Processing Record 37 of Set 11 | merano
# Processing Record 38 of Set 11 | zavetnoye
# Processing Record 39 of Set 11 | road town
# Processing Record 40 of Set 11 | haimen
# Processing Record 41 of Set 11 | ilomantsi
# Processing Record 42 of Set 11 | susuman
# Processing Record 43 of Set 11 | lhokseumawe
# Processing Record 44 of Set 11 | nizhneudinsk
# Processing Record 45 of Set 11 | tevragh zeina
# City not found. Skipping...
# Processing Record 46 of Set 11 | nuku'alofa
# Processing Record 47 of Set 11 | cururupu
# Processing Record 48 of Set 11 | kot ghulam muhammad
# Processing Record 49 of Set 11 | sal rei
# Processing Record 0 of Set 12 | dombarovskiy
# Processing Record 1 of Set 12 | maitum
# Processing Record 2 of Set 12 | giado
# Processing Record 3 of Set 12 | shar
# Processing Record 4 of Set 12 | cooper's town
# Processing Record 5 of Set 12 | arraial do cabo
# Processing Record 6 of Set 12 | petropavlovka
# Processing Record 7 of Set 12 | mingshui
# Processing Record 8 of Set 12 | berberati
# Processing Record 9 of Set 12 | lazaro cardenas
# Processing Record 10 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 11 of Set 12 | vangaindrano
# Processing Record 12 of Set 12 | gaalkacyo
# Processing Record 13 of Set 12 | mount gambier
# Processing Record 14 of Set 12 | menderes
# Processing Record 15 of Set 12 | cacule
# Processing Record 16 of Set 12 | tazacorte
# Processing Record 17 of Set 12 | mersing
# Processing Record 18 of Set 12 | wamba
# Processing Record 19 of Set 12 | langzhong
# Processing Record 20 of Set 12 | cartagena
# Processing Record 21 of Set 12 | turpan
# Processing Record 22 of Set 12 | nishinoomote
# Processing Record 23 of Set 12 | chiredzi
# Processing Record 24 of Set 12 | bandar abbas
# Processing Record 25 of Set 12 | inza
# Processing Record 26 of Set 12 | ulanhot
# Processing Record 27 of Set 12 | fort mcmurray
# Processing Record 28 of Set 12 | kwidzyn
# Processing Record 29 of Set 12 | lesozavodsk
# Processing Record 30 of Set 12 | houlton
# Processing Record 31 of Set 12 | helena valley southeast
# Processing Record 32 of Set 12 | taro
# Processing Record 33 of Set 12 | svendborg
# Processing Record 34 of Set 12 | fortaleza
# Processing Record 35 of Set 12 | astrakhan
# Processing Record 36 of Set 12 | barkhan
# Processing Record 37 of Set 12 | zarand
# Processing Record 38 of Set 12 | jeremie
# Processing Record 39 of Set 12 | taseyevo
# Processing Record 40 of Set 12 | nejo
# Processing Record 41 of Set 12 | sokode
# Processing Record 42 of Set 12 | richards bay
# Processing Record 43 of Set 12 | butte
# Processing Record 44 of Set 12 | mermoz boabab
# Processing Record 45 of Set 12 | as suwayq
# Processing Record 46 of Set 12 | saint-leu
# Processing Record 47 of Set 12 | palangkaraya
# Processing Record 48 of Set 12 | espinosa
# Processing Record 49 of Set 12 | srandakan
# Processing Record 0 of Set 13 | soller
# Processing Record 1 of Set 13 | al bayda'
# Processing Record 2 of Set 13 | akureyri
# Processing Record 3 of Set 13 | i-n-salah
# Processing Record 4 of Set 13 | itumba
# Processing Record 5 of Set 13 | al bardiyah
# Processing Record 6 of Set 13 | yinchuan
# Processing Record 7 of Set 13 | rosario
# Processing Record 8 of Set 13 | barra de santo antonio
# Processing Record 9 of Set 13 | labuan
# Processing Record 10 of Set 13 | zajas
# Processing Record 11 of Set 13 | ebish
# Processing Record 12 of Set 13 | la passe
# Processing Record 13 of Set 13 | port shepstone
# Processing Record 14 of Set 13 | pontianak
# Processing Record 15 of Set 13 | derzhavinsk
# Processing Record 16 of Set 13 | parral
# Processing Record 17 of Set 13 | mangrol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   bechar  31.6167   -2.2167     32.10        15         100
# 1                   anadyr  64.7500  177.4833    -10.72        85           0
# 2        port-aux-francais -49.3500   70.2167      1.57        71          71
# 3            port mathurin -19.6833   63.4167     24.09        77           7
# 4                    tiksi  71.6872  128.8694    -11.66        98          74
#
#          Wind Speed Country        Date
# City_ID
# 0             13.22      DZ  1697728035
# 1              5.00      RU  1697728035
# 2              7.87      TF  1697728035
# 3              5.73      MU  1697728035
# 4              0.74      RU  1697728036

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      tralee  52.2704   -9.7026     16.14        82
# 1        vila franca do campo  37.7167  -25.4333     20.23        99
# 2         spittal an der drau  46.8000   13.5000     12.94       100
# 3                      hasaki  35.7333  140.8333     17.38        69
# 4                invercargill -46.4000  168.3500     10.57        96
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        2.57      IE  1697735577
# 1                16        7.64      PT  1697735577
# 2               100        1.09      AT  1697735578
# 3                62        6.35      JP  1697735578
# 4                96        3.58      NZ  1697735578

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')


# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs.Humidity(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed(2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      tralee  52.2704   -9.7026     16.14        82
# 1        vila franca do campo  37.7167  -25.4333     20.23        99
# 2         spittal an der drau  46.8000   13.5000     12.94       100
# 3                      hasaki  35.7333  140.8333     17.38        69
# 5               valle hermoso  25.6667  -97.8333     29.94        47
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                40        2.57      IE  1697735577
# 1                16        7.64      PT  1697735577
# 2               100        1.09      AT  1697735578
# 3                62        6.35      JP  1697735578
# 5                86        4.73      MX  1697735442

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4             invercargill -46.4000  168.3500     10.57        96          96
# 6           puerto natales -51.7236  -72.4875     15.25        38          40
# 8        port-aux-francais -49.3500   70.2167      1.69        70          54
# 9                papatowai -46.5619  169.4708     10.77        83         100
# 11               adamstown -25.0660 -130.1015     22.00        86          19
#
#          Wind Speed Country        Date
# City_ID
# 4              3.58      NZ  1697735578
# 6              8.23      CL  1697735578
# 8              6.64      TF  1697735579
# 9              6.10      NZ  1697735579
# 11             5.19      PN  1697735579

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# The r-value between Lat and Max Temp is -0.84
# Text(0, 0.5, 'Temperature(C)')

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# The r-value between Lat and Max Temp is 0.7
# Text(0, 0.5, 'Temperature(C)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and temperature have a strong negative coorelation(-0.81) - that is to say the higher latitude of the city, the lower temperature the city would be. On the contrary, in southern hemisphere, a city's latitude and temperature have a fair positive coorelation(0.73) - that is to say the higher latitude of the city, the higher temperature the city would be.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],(55, 10))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is 0.21
# Text(0, 0.5, 'Humidity(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],(-50, 25))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
# Out:
# The r-value between Lat and Humidity is 0.02
# Text(0, 0.5, 'Humidity(%)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and humidity have a weak positive coorelation(0.16) - that is to say with latitude increase, city's humidity is likely to increase but not much, in southern hemisphere, a city's latitude and humidity also have a weak positive coorelation(0.08) - that is to say with latitude increase, city's humidity is likely to increase but quick minimal.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],(50, 50))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is 0.18
# Text(0, 0.5, 'Cloudiness(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],(-50, 65))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
# Out:
# The r-value between Lat and Cloudiness is 0.07
# Text(0, 0.5, 'Cloudiness(%)')

# %% [markdown]
# **Discussion about the linear relationship:** In northern hemisphere, a city's latitude and cloudiness level have almost no coorelation(0.02) - that is to say a city's cloudiness level does not much related to its latitude, in southern hemisphere, it is a similar situation with almost no coorelation(0.17) between city's latitude and cloudiness level.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],(10, 12))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is 0.24
# Text(0, 0.5, 'Wind Speed(m/s)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],(-50, 9))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
# Out:
# The r-value between Lat and Wind Speed is -0.29
# Text(0, 0.5, 'Wind Speed(m/s)')

# %% [markdown]
# **Discussion about the linear relationship:** n northern hemisphere, a city's latitude and wind speed have no coorelation(0.00) - that is to say a city's windy level does not much related to its latitude, in southern hemisphere, it is a similar situation with very minor negative coorelation(-0.17) between city's latitude and wind speed.
